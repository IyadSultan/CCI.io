# %% [markdown]
# # Lab 1: Your First Clinical Python Notebook
# ## CCI Session 2 - Python Fundamentals
#
# **Duration:** 10 minutes
# **Mode:** Guided step-by-step
#
# ### Clinical Scenario
# > You are a data analyst at KHCC and receive a daily list of patients with their hemoglobin and WBC counts. You need to flag abnormal values automatically instead of checking them manually.
#
# ### Objective
# By the end of this lab, you will have a working Colab notebook that:
# - Stores patient data in variables and dictionaries
# - Loops through lab results
# - Prints clinical alerts for abnormal values
#
# ### Reference Thresholds
# - Hemoglobin < 10.0 g/dL = **LOW**
# - WBC > 11.0 x10^9/L = **HIGH**
# - WBC < 4.0 x10^9/L = **LOW**

# %% [markdown]
# ---
# ## Cell 1 - Variables
# Create variables for a single patient:
# - `patient_name` (string)
# - `mrn` (string)
# - `hemoglobin` (float)
# - `wbc` (float)
# - `on_chemo` (boolean)
#
# Print all of them.

# %%
# === CELL 1: VARIABLES ===

# TODO: Create a variable called patient_name and assign it the value "Ahmad"
patient_name = None

# TODO: Create a variable called mrn and assign it "P-1001"
mrn = None

# TODO: Create a variable called hemoglobin and assign it 9.1
hemoglobin = None

# TODO: Create a variable called wbc and assign it 6.2
wbc = None

# TODO: Create a variable called on_chemo and assign it True
on_chemo = None

# TODO: Print all five variables using print()

# %% [markdown]
# ---
# ## Cell 2 - Dictionary
# Store the same patient as a dictionary with keys: `name`, `mrn`, `hgb`, `wbc`, `on_chemo`.
# Access and print each value using bracket notation.

# %%
# === CELL 2: DICTIONARY ===

# TODO: Create a dictionary called 'patient' with keys: name, mrn, hgb, wbc, on_chemo
# Use the same values as Cell 1
patient = {
    # TODO: Fill in the key-value pairs
}

# TODO: Print the patient's name using bracket notation: patient["name"]

# TODO: Print the patient's hemoglobin using bracket notation

# TODO: Print the entire dictionary

# %% [markdown]
# ---
# ## Cell 3 - List of Patients
# Create a list of 5 dictionaries, each representing a patient with different lab values.
# Use the KHCC mock data below:
#
# | Name   | MRN    | HGB  | WBC  | On Chemo |
# |--------|--------|------|------|----------|
# | Ahmad  | P-1001 | 9.1  | 6.2  | True     |
# | Sara   | P-1002 | 13.5 | 12.3 | False    |
# | Khaled | P-1003 | 7.8  | 3.5  | True     |
# | Lina   | P-1004 | 11.2 | 7.1  | False    |
# | Omar   | P-1005 | 8.5  | 9.8  | True     |

# %%
# === CELL 3: LIST OF PATIENTS ===

# TODO: Create a list called 'patients' containing 5 dictionaries
# Each dictionary should have keys: name, mrn, hgb, wbc, on_chemo
patients = [
    # TODO: Add Ahmad's record
    # TODO: Add Sara's record
    # TODO: Add Khaled's record
    # TODO: Add Lina's record
    # TODO: Add Omar's record
]

# Print to verify
print(f"Total patients: {len(patients)}")

# %% [markdown]
# ---
# ## Cell 4 - Alert Loop
# Write a `for` loop that iterates through the patient list and prints a warning if:
# - Hemoglobin < 10.0 (LOW)
# - WBC > 11.0 (HIGH)
# - WBC < 4.0 (LOW)

# %%
# === CELL 4: ALERT LOOP ===

# TODO: Write a for loop that goes through each patient in the patients list
# For each patient, check:
#   - If hgb < 10.0, print: "ALERT: Patient [name] - Hemoglobin [value] (LOW)"
#   - If wbc > 11.0, print: "ALERT: Patient [name] - WBC [value] (HIGH)"
#   - If wbc < 4.0, print: "ALERT: Patient [name] - WBC [value] (LOW)"

# Hint: Use a for loop like: for p in patients:
# Hint: Access values with p["hgb"] and p["name"]

# %% [markdown]
# ---
# ## Cell 5 - Summary
# Print a count of how many patients have at least one abnormal value.

# %%
# === CELL 5: SUMMARY ===

# TODO: Create a variable 'abnormal_count' starting at 0
abnormal_count = 0

# TODO: Loop through patients and increment abnormal_count
# if the patient has hgb < 10 OR wbc > 11 OR wbc < 4


# TODO: Print the summary message
# Expected: "Summary: X of 5 patients have abnormal values"

# %% [markdown]
# ---
# ## Stretch Challenge
# Add a severity classification for hemoglobin:
# - < 7.0 = **CRITICAL**
# - 7.0 - 10.0 = **LOW**
# - >= 10.0 = **NORMAL**

# %%
# === STRETCH CHALLENGE ===

# TODO: Write a loop that classifies each patient's hemoglobin
# as CRITICAL, LOW, or NORMAL and prints the result

# %% [markdown]
# ---
# ### Expected Output
# ```
# ALERT: Patient Ahmad - Hemoglobin 9.1 (LOW)
# ALERT: Patient Sara - WBC 12.3 (HIGH)
# ALERT: Patient Khaled - Hemoglobin 7.8 (LOW)
# ALERT: Patient Khaled - WBC 3.5 (LOW)
# ALERT: Patient Omar - Hemoglobin 8.5 (LOW)
# Summary: 4 of 5 patients have abnormal values
# ```
#
# ### KHCC Connection
# > This mirrors the daily lab review process used by the AIDI team to flag abnormal results before morning rounds.
