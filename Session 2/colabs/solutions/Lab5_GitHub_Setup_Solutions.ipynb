# %% [markdown]
# # Lab 5: Setting Up GitHub and Pushing Your First Clinical Notebook - SOLUTIONS
# ## CCI Session 2 - GitHub Fundamentals
#
# **Duration:** 10 minutes
# **Mode:** Guided step-by-step
#
# ### Clinical Scenario
# > KHCC's AIDI team requires all clinical notebooks to be stored in version control. You are setting up your personal GitHub repository to track all work from this course.
#
# ### Note
# This lab is primarily GUI-based (browser steps). The solutions below show the git commands and expected results for the code cells.

# %% [markdown]
# ---
# ## Step 1: Create Your GitHub Account
#
# 1. Go to [github.com](https://github.com) and click **Sign up**
# 2. Use your KHCC or personal email
# 3. Choose a professional username (e.g., `ahmad-khcc`)
# 4. Complete the setup

# %% [markdown]
# ---
# ## Step 2: Create a New Repository
#
# Settings to use:
# - **Name:** `cci-course-notebooks`
# - **Description:** "CCI Prompt Engineering & Clinical AI Development -- Course Notebooks"
# - **Visibility:** Public or Private
# - **Initialize:** Add README, Python .gitignore

# %% [markdown]
# ---
# ## Step 3: Push Notebooks from Colab
#
# Use **File > Save a copy in GitHub** for each notebook.
#
# Recommended commit messages:
# - `Add Session 2 Lab 1 -- Python fundamentals with patient data variables and alert loop`
# - `Add Session 2 Lab 2 -- Clinical notebook template with 9-section structure`
# - `Add Session 2 Lab 3 -- Patient and OncologyPatient class hierarchy`
# - `Add Session 2 Lab 4 -- Pandas merging of demographics, labs, and medications`

# %% [markdown]
# ---
# ## Step 4: Verify on GitHub
#
# Navigate to your repository and check:
# - Files appear under `session_2/` folder
# - GitHub renders the .ipynb files
# - Commit history shows multiple descriptive commits

# %% [markdown]
# ---
# ## Test: Git Commands in Colab

# %%
# Test that git is available in Colab
# !git --version

# %% [markdown]
# **Expected output:** `git version 2.x.x` (version number may vary)

# %%
# Clone your repository (replace YOUR_USERNAME with your actual GitHub username)
# Example:
# !git clone https://github.com/ahmad-khcc/cci-course-notebooks.git

# For demonstration, we'll show what the output looks like:
print("To clone your repo, run:")
print("!git clone https://github.com/YOUR_USERNAME/cci-course-notebooks.git")
print()
print("Expected output:")
print("Cloning into 'cci-course-notebooks'...")
print("remote: Enumerating objects: 12, done.")
print("Receiving objects: 100% (12/12), done.")

# %%
# List repository contents and view commit log
# !ls cci-course-notebooks/
# !cd cci-course-notebooks && git log --oneline

print("Expected directory listing:")
print("README.md  .gitignore  session_2/")
print()
print("Expected git log:")
print("abc1234 Add Session 2 Lab 4 -- Pandas merging of clinical datasets")
print("def5678 Add Session 2 Lab 2 -- Clinical notebook template")
print("ghi9012 Initial commit")

# %% [markdown]
# ---
# ## Completed Checklist
#
# - [x] GitHub account created with a professional username
# - [x] Repository `cci-course-notebooks` created with README and .gitignore
# - [x] At least 2 notebooks pushed to `session_2/` folder
# - [x] Each push has a descriptive commit message
# - [x] Commit history shows 3+ commits
# - [x] No real patient data in any pushed notebook

# %% [markdown]
# ---
# ### Stretch Challenge Solution - README Table
#
# Edit your README.md on GitHub to include:
#
# ```markdown
# # CCI Course Notebooks
#
# ## Session 2: Python Basics + GitHub
#
# | Notebook | Description |
# |----------|-------------|
# | Lab 1 - Python Fundamentals | Variables, dictionaries, loops, lab alert system |
# | Lab 2 - Notebook Template | 9-section clinical notebook structure |
# | Lab 3 - Python Classes | Patient and OncologyPatient class hierarchy |
# | Lab 4 - Pandas Merging | Merge demographics, labs, medications datasets |
# | Lab 5 - GitHub Setup | Version control setup and first push |
# ```
#
# ### KHCC Connection
# > All AIDI production code is stored in Azure DevOps with mandatory commit messages and code review. Learning GitHub now builds the version control discipline required for the AIDI team's development workflow.
